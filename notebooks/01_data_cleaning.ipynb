# %%
# 1. Imports & configuration
import os, sys
from pathlib import Path
import pandas as pd

sys.path.append(os.path.abspath('../'))
from scripts.config import RAW_DATA_PATH, PROCESSED_DATA_PATH  # paths defined in project config

RAW_PATH = Path(RAW_DATA_PATH)
PROC_PATH = Path(PROCESSED_DATA_PATH)
PROC_PATH.parent.mkdir(parents=True, exist_ok=True)

pd.set_option('display.max_columns', 100)
print(f"RAW -> {RAW_PATH}\nPROCESSED -> {PROC_PATH}")
# Out:
# RAW -> ..\data\raw\dataset.csv
# PROCESSED -> ..\data\processed\esg_data_cleaned.csv

# %%
# 2. Load raw data
if not RAW_PATH.exists():
    raise FileNotFoundError(f"Raw dataset not found at {RAW_PATH}")
raw_df = pd.read_csv(RAW_PATH)
print(f"Raw data shape: {raw_df.shape}")
raw_df.head()
# Out:
# Raw data shape: (503, 15)
#   Symbol                      Name  \
# 0   ENPH      Enphase Energy, Inc.
# 1    EMN  Eastman Chemical Company
# 2    DPZ       Domino's Pizza Inc.
# 3    DAY            Dayforce, Inc.
# 4    DVA               Davita Inc.
#
#                                              Address             Sector  \
# 0  47281 Bayside Parkway\nFremont, CA 94538\nUnit...         Technology
# 1  200 South Wilcox Drive\nKingsport, TN 37662\nU...    Basic Materials
# 2  30 Frank Lloyd Wright Drive\nAnn Arbor, MI 481...  Consumer Cyclical
# 3  3311 East Old Shakopee Road\nMinneapolis, MN 5...         Technology
# 4  2000 16th Street\nDenver, CO 80202\nUnited States         Healthcare
#
#                   Industry Full Time Employees  \
# 0                    Solar               3,157
# 1      Specialty Chemicals              14,000
# 2              Restaurants               6,500
# 3   Software - Application               9,084
# 4  Medical Care Facilities              70,000
#
#                                          Description  Total ESG Risk score  \
# 0  Enphase Energy, Inc., together with its subsid...                   NaN
# 1  Eastman Chemical Company operates as a special...                  25.3
# 2  Domino's Pizza, Inc., through its subsidiaries...                  29.2
# 3  Dayforce Inc., together with its subsidiaries,...                   NaN
# 4  DaVita Inc. provides kidney dialysis services ...                  22.6
#
#    Environment Risk Score  Governance Risk Score  Social Risk Score  \
# 0                     NaN                    NaN                NaN
# 1                    12.8                    6.6                5.8
# 2                    10.6                    6.3               12.2
# 3                     NaN                    NaN                NaN
# 4                     0.1                    8.4               14.1
#
#             Controversy Level  Controversy Score ESG Risk Percentile  \
# 0                         NaN                NaN                 NaN
# 1  Moderate Controversy Level                2.0     50th percentile
# 2  Moderate Controversy Level                2.0     66th percentile
# 3                         NaN                NaN                 NaN
# 4  Moderate Controversy Level                2.0     38th percentile
#
#   ESG Risk Level
# 0            NaN
# 1         Medium
# 2         Medium
# 3            NaN
# 4         Medium

# %%
# 3. Basic cleaning (placeholder logic - customize as needed)
# Strip column names
if hasattr(raw_df.columns, 'str'):
    raw_df.columns = raw_df.columns.str.strip()

# Example: drop completely empty columns
empty_cols = [c for c in raw_df.columns if raw_df[c].isna().all()]
if empty_cols:
    raw_df = raw_df.drop(columns=empty_cols)

# Example: fill simple numeric missing values with median
num_cols = raw_df.select_dtypes(include=['int64','float64']).columns
raw_df[num_cols] = raw_df[num_cols].fillna(raw_df[num_cols].median())

clean_df = raw_df.copy()
print(f"Columns removed: {empty_cols}")
print(f"Cleaned shape: {clean_df.shape}")
clean_df.head()
# Out:
# Columns removed: []
# Cleaned shape: (503, 15)
#   Symbol                      Name  \
# 0   ENPH      Enphase Energy, Inc.
# 1    EMN  Eastman Chemical Company
# 2    DPZ       Domino's Pizza Inc.
# 3    DAY            Dayforce, Inc.
# 4    DVA               Davita Inc.
#
#                                              Address             Sector  \
# 0  47281 Bayside Parkway\nFremont, CA 94538\nUnit...         Technology
# 1  200 South Wilcox Drive\nKingsport, TN 37662\nU...    Basic Materials
# 2  30 Frank Lloyd Wright Drive\nAnn Arbor, MI 481...  Consumer Cyclical
# 3  3311 East Old Shakopee Road\nMinneapolis, MN 5...         Technology
# 4  2000 16th Street\nDenver, CO 80202\nUnited States         Healthcare
#
#                   Industry Full Time Employees  \
# 0                    Solar               3,157
# 1      Specialty Chemicals              14,000
# 2              Restaurants               6,500
# 3   Software - Application               9,084
# 4  Medical Care Facilities              70,000
#
#                                          Description  Total ESG Risk score  \
# 0  Enphase Energy, Inc., together with its subsid...                 21.05
# 1  Eastman Chemical Company operates as a special...                 25.30
# 2  Domino's Pizza, Inc., through its subsidiaries...                 29.20
# 3  Dayforce Inc., together with its subsidiaries,...                 21.05
# 4  DaVita Inc. provides kidney dialysis services ...                 22.60
#
#    Environment Risk Score  Governance Risk Score  Social Risk Score  \
# 0                    4.05                    6.1                8.9
# 1                   12.80                    6.6                5.8
# 2                   10.60                    6.3               12.2
# 3                    4.05                    6.1                8.9
# 4                    0.10                    8.4               14.1
#
#             Controversy Level  Controversy Score ESG Risk Percentile  \
# 0                         NaN                2.0                 NaN
# 1  Moderate Controversy Level                2.0     50th percentile
# 2  Moderate Controversy Level                2.0     66th percentile
# 3                         NaN                2.0                 NaN
# 4  Moderate Controversy Level                2.0     38th percentile
#
#   ESG Risk Level
# 0            NaN
# 1         Medium
# 2         Medium
# 3            NaN
# 4         Medium

# %%
# 4. Persist processed data
clean_df.to_csv(PROC_PATH, index=False)
print(f"✅ Saved processed dataset to {PROC_PATH}")
# Out:
# ✅ Saved processed dataset to ..\data\processed\esg_data_cleaned.csv

# %%
# 5. Quick quality report
missing_summary = clean_df.isnull().sum().sort_values(ascending=False)
print("Missing values (top 20):")
print(missing_summary.head(20))

print("\nDescriptive stats:")
clean_df.describe(include='all').transpose().head(25)
# Out:
# Missing values (top 20):
# Controversy Level         73
# ESG Risk Percentile       73
# ESG Risk Level            73
# Full Time Employees        5
# Address                    1
# Sector                     1
# Industry                   1
# Description                1
# Symbol                     0
# Name                       0
# Total ESG Risk score       0
# Environment Risk Score     0
# Governance Risk Score      0
# Social Risk Score          0
# Controversy Score          0
# dtype: int64
#
# Descriptive stats:
#                         count unique  \
# Symbol                    503    503
# Name                      503    503
# Address                   502    498
# Sector                    502     11
# Industry                  502    116
# Full Time Employees       498    394
# Description               502    499
# Total ESG Risk score    503.0    NaN
# Environment Risk Score  503.0    NaN
# Governance Risk Score   503.0    NaN
# Social Risk Score       503.0    NaN
# Controversy Level         430      6
# Controversy Score       503.0    NaN
# ESG Risk Percentile       430     89
# ESG Risk Level            430      5
#
#                                                                       top  \
# Symbol                                                               ENPH
# Name                                                 Enphase Energy, Inc.
# Address                 1211 Avenue of the Americas\nNew York, NY 1003...
# Sector                                                         Technology
# Industry                                   Utilities - Regulated Electric
# Full Time Employees                                                18,000
# Description             Alphabet Inc. offers various products and plat...
# Total ESG Risk score                                                  NaN
# Environment Risk Score                                                NaN
# Governance Risk Score                                                 NaN
# Social Risk Score                                                     NaN
# Controversy Level                              Moderate Controversy Level
# Controversy Score                                                     NaN
# ESG Risk Percentile                                       16th percentile
# ESG Risk Level                                                        Low
#
#                        freq       mean       std  min   25%    50%    75%  \
# Symbol                    1        NaN       NaN  NaN   NaN    NaN    NaN
# Name                      1        NaN       NaN  NaN   NaN    NaN    NaN
# Address                   4        NaN       NaN  NaN   NaN    NaN    NaN
# Sector                   76        NaN       NaN  NaN   NaN    NaN    NaN
# Industry                 23        NaN       NaN  NaN   NaN    NaN    NaN
# Full Time Employees      10        NaN       NaN  NaN   NaN    NaN    NaN
# Description               2        NaN       NaN  NaN   NaN    NaN    NaN
# Total ESG Risk score    NaN  21.463519  6.370885  7.1  16.9  21.05  25.15
# Environment Risk Score  NaN   5.494533  4.745167  0.0   2.0   4.05    8.0
# Governance Risk Score   NaN   6.634394  2.053097  3.0   5.4    6.1    7.4
# Social Risk Score       NaN   9.045726   3.38205  0.8   7.2    8.9   10.8
# Controversy Level       199        NaN       NaN  NaN   NaN    NaN    NaN
# Controversy Score       NaN   2.005964  0.709893  1.0   2.0    2.0    2.0
# ESG Risk Percentile      12        NaN       NaN  NaN   NaN    NaN    NaN
# ESG Risk Level          187        NaN       NaN  NaN   NaN    NaN    NaN
#
#                          max
# Symbol                   NaN
# Name                     NaN
# Address                  NaN
# Sector                   NaN
# Industry                 NaN
# Full Time Employees      NaN
# Description              NaN
# Total ESG Risk score    41.7
# Environment Risk Score  25.0
# Governance Risk Score   19.4
# Social Risk Score       22.5
# Controversy Level        NaN
# Controversy Score        5.0
# ESG Risk Percentile      NaN
# ESG Risk Level           NaN
